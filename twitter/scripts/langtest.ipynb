# %%
from langua import Predict

# %%
predictor = Predict()

# %%
print(predictor.get_lang("Det här är en text lol"))
print(predictor.get_lang("lol Det här är en text"))
print(predictor.get_lang("lol this tbh är en text mood rn"))
# Out:
# sv
# sv
# sv

# %%
print(predictor.get_lang("this tbh mood smh fam jag hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar hatar apor"))
# Out:
# id
