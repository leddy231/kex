# %%
import gensim

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('C:/Users/marti/Documents/word2vec/GoogleNews-word2vec.bin', binary=True)

# %%
print(model.distance("bad", "google"))
print(model.distance("good", "google"))
# Out:
# 0.7917764484882355
# 0.8197403848171234

# %%
print(model.distance("bad", "microsoft"))
print(model.distance("good", "microsoft"))
# Out:
# 0.8743716478347778
# 0.9500997476279736

# %%
model.distance("microsoft", "google")
# Out:
# 0.6761711835861206

# %%
model.distance("apple", "google")
# Out:
# 0.7722519934177399

# %%
model.most_similar("google")
# Out:
# [('google.com', 0.6711486577987671),
#  ('google_yahoo', 0.6488178968429565),
#  ('wikipedia', 0.6436079740524292),
#  ('www.google.com', 0.6258559226989746),
#  ('googled', 0.6166063547134399),
#  ('googling', 0.6086059212684631),
#  ('slashdot', 0.5964587926864624),
#  ('lifehacker', 0.5948860049247742),
#  ('gizmodo', 0.5884420871734619),
#  ('inurl', 0.5882638692855835)]

# %%
model.most_similar("apple")
# Out:
# [('apples', 0.720359742641449),
#  ('pear', 0.6450697183609009),
#  ('fruit', 0.641014575958252),
#  ('berry', 0.6302294135093689),
#  ('pears', 0.6133961081504822),
#  ('strawberry', 0.6058261394500732),
#  ('peach', 0.6025872230529785),
#  ('potato', 0.5960935354232788),
#  ('grape', 0.5935864448547363),
#  ('blueberry', 0.5866668224334717)]

# %%
model.most_similar("microsoft")
# Out:
# [('adobe_photoshop', 0.8042365312576294),
#  ('microsoft_office', 0.7978680729866028),
#  ('windows_xp', 0.7926486134529114),
#  ('buy_microsoft', 0.7902630567550659),
#  ('cs4', 0.7494896650314331),
#  ('autocad', 0.7432770729064941),
#  ('photoshop', 0.7404437065124512),
#  ('windows_vista', 0.7382056713104248),
#  ('quickbooks', 0.7320875525474548),
#  ('adobe_photoshop_cs4', 0.7269179821014404)]

# %%
model.most_similar("windows")
# Out:
# [('window', 0.7260905504226685),
#  ('panes', 0.6087879538536072),
#  ('window_panes', 0.6025022268295288),
#  ('double_paned', 0.5940830707550049),
#  ('Leaded_glass', 0.5917976498603821),
#  ('including_overhead_portholes', 0.5890442132949829),
#  ('glass_panes', 0.5884373188018799),
#  ('double_paned_windows', 0.5841959118843079),
#  ('Shopkeepers_boarded', 0.5798099040985107),
#  ('drapes_blinds', 0.5736609101295471)]

# %%
model.most_similar("trump")
# Out:
# [('trumps', 0.7198435068130493),
#  ('trumping', 0.580585241317749),
#  ('supersede', 0.5600422620773315),
#  ('trumped', 0.5497317910194397),
#  ('supercede', 0.5309919118881226),
#  ('prevail', 0.48776334524154663),
#  ('outweigh', 0.4785327613353729),
#  ('trample', 0.471425324678421),
#  ('overshadow', 0.4701153635978699),
#  ('dictate', 0.46754559874534607)]

# %%
model.most_similar("hillary_clinton")
# Out:
# [('john_mccain', 0.7577487826347351),
#  ('barack_obama', 0.7538372874259949),
#  ('mccain', 0.7498881816864014),
#  ('hillary', 0.737309455871582),
#  ('michelle_obama', 0.7206136584281921),
#  ('palin', 0.7084476947784424),
#  ('ron_paul', 0.6998802423477173),
#  ('george_bush', 0.6619243621826172),
#  ('barack', 0.6596920490264893),
#  ('democrate', 0.6583254337310791)]

# %%
model.most_similar("republican")
# Out:
# [('republicans', 0.7488651275634766),
#  ('republicanism', 0.6348801851272583),
#  ('democrat', 0.6315850019454956),
#  ('Unionist', 0.6078413128852844),
#  ('democrats', 0.6074379682540894),
#  ('unionist', 0.565619945526123),
#  ('Republican', 0.5576926469802856),
#  ('liberal_democrat', 0.5513334274291992),
#  ('Ulster_Unionism', 0.5434642434120178),
#  ('john_mccain', 0.5420000553131104)]

# %%
model.most_similar("democrat")
# Out:
# [('democrats', 0.7569220066070557),
#  ('liberal_democrat', 0.7053179144859314),
#  ('Democrat', 0.635062575340271),
#  ('republican', 0.6315850019454956),
#  ('politician', 0.610986590385437),
#  ('repub', 0.6045383214950562),
#  ('democrates', 0.6032745242118835),
#  ('politican', 0.5956685543060303),
#  ('democrate', 0.5861297249794006),
#  ('socialist', 0.5848069190979004)]
